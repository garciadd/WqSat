# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

## WQ_SAT
from wq_sat import config
from wq_sat.satellites import sentinel2
from wq_sat.utils import geo_utils

# %%
def get_bands(tiles, coordinates=None):
    
    tile_path = config.acolite_path(tiles[0])
    data_bands, coord = sentinel2.Rs_acolite(tile_path, coordinates)
    h, w = data_bands['B2'].shape

    ## Bands
    Rs492 = np.zeros((h, w, len(tiles)))
    Rs559 = np.zeros((h, w, len(tiles)))
    Rs665 = np.zeros((h, w, len(tiles)))
    Rs704 = np.zeros((h, w, len(tiles)))
    Rs842 = np.zeros((h, w, len(tiles)))
    chl = np.zeros((h, w, len(tiles)))
    
    for t, tile in enumerate(tiles):

        tile_path = config.acolite_path(tile)
        data_bands, coord = sentinel2.Rs_acolite(tile_path, coordinates)

        ## Bands
        Rs492[:,:,t] = data_bands['B2']
        Rs559[:,:,t] = data_bands['B3']
        Rs665[:,:,t] = data_bands['B4']
        Rs704[:,:,t] = data_bands['B5']
        Rs842[:,:,t] = data_bands['B8']
        chl[:,:,t] = data_bands['chl']

    ## Bands quality proxies
    Rs492_c = np.nanmax(Rs492, axis=2) # Rs492 -> B2
    Rs559_c = np.nanmax(Rs559, axis=2) # Rs559 -> B3
    Rs665_c = np.nanmax(Rs665, axis=2) # Rs665 -> B4
    Rs704_c = np.nanmax(Rs704, axis=2) # Rs704 -> B5
    Rs842_c = np.nanmax(Rs842, axis=2) # Rs842 -> B8
    chl_c = np.nanmax(chl, axis=2) # chl
    
    return Rs492_c, Rs559_c, Rs665_c, Rs704_c, Rs842_c, chl_c

# %%
region = 'Muro'
year = '2023'

path = os.path.join(config.data_path(), 'bathymetries', region, 'InSitu')
file = '{}_Insitu_bathymetry_EPSG32631_{}.tif'.format(region, year)

bathymetry, BBox, crs = geo_utils.load_geotiff(os.path.join(path, file))
mx = np.ma.masked_invalid(bathymetry)

# ROI
## transform coordinates
new_ul = geo_utils.transform_coordinates(BBox[0], inputEPSG=crs, outputEPSG=4326)
new_lr = geo_utils.transform_coordinates(BBox[1], inputEPSG=crs, outputEPSG=4326)
roi_coord = {'N': new_ul[0], 'W': new_ul[1], 'S': new_lr[0], 'E': new_lr[1]}

## tiles
tiles = config.get_tiles(region, year)

## Rs Bands
Rs492, Rs559, Rs665, Rs704, Rs842, chl = get_bands(tiles, roi_coord)
Rs492[mx.mask] = np.nan
Rs559[mx.mask] = np.nan
Rs665[mx.mask] = np.nan
Rs704[mx.mask] = np.nan
Rs842[mx.mask] = np.nan
chl[mx.mask] = np.nan

df_arr = np.vstack((bathymetry.flatten(),
                    Rs492.flatten(), 
                    Rs559.flatten(), 
                    Rs665.flatten(), 
                    Rs704.flatten(), 
                    Rs842.flatten(),
                    chl.flatten()))

df_arr = np.transpose(df_arr)
df = pd.DataFrame(df_arr, 
                  columns = ['Bathymetry', 'B2','B3','B4', 'B5', 'B8', 'chl'])

var = ['B2','B3','B4', 'B5', 'B8']
for v in var:
    print('Band: {} -> p1: {}'.format(v, np.nanpercentile(df[v], 1)))
    df[v][df[v] < np.nanpercentile(df[v], 1)] = np.nan
    
## Ratios transform
df['Rt23'] = np.log(3140*df['B2'])/np.log(3140*df['B3'])
df['Rt24'] = np.log(3140*df['B2'])/np.log(3140*df['B4'])
df['Rt28'] = np.log(3140*df['B2'])/np.log(3140*df['B8'])
df['Rt34'] = np.log(3140*df['B3'])/np.log(3140*df['B4'])
df['Rt38'] = np.log(3140*df['B3'])/np.log(3140*df['B8'])
df['Rt48'] = np.log(3140*df['B4'])/np.log(3140*df['B8'])

## Lyzenga transform
df['Lt2'] = np.log(df['B2'] - np.nanmin(df['B2']))
df['Lt3'] = np.log(df['B3'] - np.nanmin(df['B3']))
df['Lt4'] = np.log(df['B4'] - np.nanmin(df['B4']))
df['Lt8'] = np.log(df['B8'] - np.nanmin(df['B8']))

df = df.replace([-np.inf], np.nan)
df.loc[df.isnull().any(axis=1), :] = np.nan

output_path = '/home/wq_sat/notebooks/bathymetries/ML_SDB/data'
df.to_csv(os.path.join(output_path, '{}_{}.csv'.format(region, year)), index = None, header=True)
# Out:
# Loading /home/wqsat_data/Sentinel-2/ACOLITE/S2B_MSIL1C_20230325T102649_N0509_R108_T31TEE_20230325T122948
# Selected pixel region: xmin=1000, ymin=9257, xmax=1109, ymax=9350:
# Image size: width=110 x height=94
# Loading /home/wqsat_data/Sentinel-2/ACOLITE/S2B_MSIL1C_20230325T102649_N0509_R108_T31TEE_20230325T122948
# Selected pixel region: xmin=1000, ymin=9257, xmax=1109, ymax=9350:
# Image size: width=110 x height=94
# Loading /home/wqsat_data/Sentinel-2/ACOLITE/S2B_MSIL1C_20230417T103629_N0509_R008_T31TEE_20230417T123856
# Selected pixel region: xmin=1000, ymin=9257, xmax=1109, ymax=9350:
# Image size: width=110 x height=94
# Loading /home/wqsat_data/Sentinel-2/ACOLITE/S2A_MSIL1C_20230320T102731_N0509_R108_T31TEE_20230320T141015
# Selected pixel region: xmin=1000, ymin=9257, xmax=1109, ymax=9350:
# Image size: width=110 x height=94
# Loading /home/wqsat_data/Sentinel-2/ACOLITE/S2A_MSIL1C_20230323T103711_N0509_R008_T31TEE_20230323T173840
# Selected pixel region: xmin=1000, ymin=9257, xmax=1109, ymax=9350:
# Image size: width=110 x height=94
# Loading /home/wqsat_data/Sentinel-2/ACOLITE/S2A_MSIL1C_20230419T102601_N0509_R108_T31TEE_20230419T154907
# Selected pixel region: xmin=1000, ymin=9257, xmax=1109, ymax=9350:
# Image size: width=110 x height=94
# Band: B2 -> p1: 0.007834786549210548
# Band: B3 -> p1: 0.0063790590036660435
# Band: B4 -> p1: 0.00124622811563313
# Band: B5 -> p1: 0.001067613719496876
# Band: B8 -> p1: 0.0008047149545745924
# /tmp/ipykernel_142864/330713726.py:29: RuntimeWarning: All-NaN slice encountered
#   Rs492_c = np.nanmax(Rs492, axis=2) # Rs492 -> B2
# /tmp/ipykernel_142864/330713726.py:30: RuntimeWarning: All-NaN slice encountered
#   Rs559_c = np.nanmax(Rs559, axis=2) # Rs559 -> B3
# /tmp/ipykernel_142864/330713726.py:31: RuntimeWarning: All-NaN slice encountered
#   Rs665_c = np.nanmax(Rs665, axis=2) # Rs665 -> B4
# /tmp/ipykernel_142864/330713726.py:32: RuntimeWarning: All-NaN slice encountered
#   Rs704_c = np.nanmax(Rs704, axis=2) # Rs704 -> B5
# /tmp/ipykernel_142864/330713726.py:33: RuntimeWarning: All-NaN slice encountered
#   Rs842_c = np.nanmax(Rs842, axis=2) # Rs842 -> B8
# /tmp/ipykernel_142864/330713726.py:34: RuntimeWarning: All-NaN slice encountered
#   chl_c = np.nanmax(chl, axis=2) # chl
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ## join data from the same regions

# %%
path = '/home/wq_sat/notebooks/bathymetries/ML_SDB/data'
region = 'SanBou'

df2018 = pd.read_csv(os.path.join(path, '{}_2017.csv'.format(region)))
df2018.loc[df2018.isnull().any(axis=1), :] = np.nan
df2018 = df2018.dropna()

df2019 = pd.read_csv(os.path.join(path, '{}_2021.csv'.format(region)))
df2019.loc[df2019.isnull().any(axis=1), :] = np.nan
df2019 = df2019.dropna()

df2020 = pd.read_csv(os.path.join(path, '{}_2022.csv'.format(region)))
df2020.loc[df2020.isnull().any(axis=1), :] = np.nan
df2020 = df2020.dropna()

df = pd.concat([df2018, df2019, df2020], axis = 0)

output_path = '/home/wq_sat/notebooks/bathymetries/ML_SDB/data'
df.to_csv(os.path.join(output_path, '{}.csv'.format(region)), index = None, header=True)

# %%
path = '/home/wq_sat/notebooks/bathymetries/ML_SDB/data'
region = 'Muro'

df2018 = pd.read_csv(os.path.join(path, '{}_2023.csv'.format(region)))
df2018.loc[df2018.isnull().any(axis=1), :] = np.nan
df2018 = df2018.dropna()

output_path = '/home/wq_sat/notebooks/bathymetries/ML_SDB/data'
df2018.to_csv(os.path.join(output_path, '{}.csv'.format(region)), index = None, header=True)

# %% [markdown]
# ## join all data

# %%
path = '/home/wq_sat/notebooks/bathymetries/ML_SDB/data'

df_CalaMillor = pd.read_csv(os.path.join(path, 'CalaMillor.csv'))

df_SanBou = pd.read_csv(os.path.join(path, 'SanBou.csv'))

df_Muro = pd.read_csv(os.path.join(path, 'Muro.csv'))

df = pd.concat([df_CalaMillor, df_SanBou, df_Muro], axis = 0)

output_path = '/home/wq_sat/notebooks/bathymetries/ML_SDB/data'
df.to_csv(os.path.join(output_path, 'bathymetry_data.csv'), index = None, header=True)

# %% [markdown]
# ## ML data analysis

# %%
df
# Out:
#       Bathymetry        B2        B3        B4        B5        B8       chl
# 0      -1.693478  0.036578  0.041910  0.016526  0.013325  0.004232  2.801855  \
# 1      -1.995529  0.035142  0.040581  0.019217  0.023148  0.007134  2.801855
# 2      -2.253562  0.034164  0.038859  0.031123  0.023148  0.018586  3.304615
# 3      -2.535824  0.029768  0.033131  0.019217  0.023148  0.007134  3.029637
# 4      -2.546011  0.028400  0.034890  0.031123  0.032117  0.016664  3.081493
# ...          ...       ...       ...       ...       ...       ...       ...
# 7598   -3.933648  0.020926  0.022472  0.004597  0.003631  0.003515  2.789381
# 7599   -2.338984  0.038383  0.045474  0.011987  0.005119  0.001412  3.191955
# 7600   -2.705085  0.035469  0.042051  0.009465  0.004760  0.002276  3.210942
# 7601   -3.022751  0.031940  0.038001  0.008251  0.004760  0.002628  3.273729
# 7602   -3.294174  0.028963  0.034069  0.006990  0.004635  0.002896  3.106083
#
#           Rt23      Rt24      Rt28      Rt34      Rt38      Rt48       Lt2
# 0     0.972110  1.201177  1.833784  1.235639  1.886396  1.526656 -3.563276  \
# 1     0.970312  1.147215  1.512882  1.182316  1.559171  1.318743 -3.615255
# 2     0.973198  1.020346  1.149693  1.048447  1.181356  1.126767 -3.652253
# 3     0.976955  1.106733  1.459497  1.132840  1.493924  1.318743 -3.838041
# 4     0.956177  0.980016  1.134718  1.024931  1.186724  1.157857 -3.903656
# ...        ...       ...       ...       ...       ...       ...       ...
# 7598  0.983246  1.567663  1.742864  1.594376  1.772562  1.111759 -4.335850
# 7599  0.965833  1.320785  3.217168  1.367508  3.330977  2.435801 -3.488441
# 7600  0.965143  1.389495  2.396329  1.439678  2.482875  1.724605 -3.588689
# 7601  0.963662  1.415908  2.183537  1.469299  2.265875  1.542147 -3.725347
# 7602  0.965245  1.460202  2.043195  1.512779  2.116763  1.399255 -3.857168
#
#            Lt3       Lt4       Lt8
# 0    -3.327024 -4.205634 -5.723626
# 1    -3.364747 -4.039726 -5.088084
# 2    -3.415842 -3.523085 -4.038568
# 3    -3.607486 -4.039726 -5.088084
# 4    -3.544633 -3.523085 -4.154093
# ...        ...       ...       ...
# 7598 -4.129356 -5.698461 -5.910617
# 7599 -3.241771 -4.533727 -7.405996
# 7600 -3.333397 -4.801359 -6.521518
# 7601 -3.453912 -4.961234 -6.307234
# 7602 -3.586671 -5.159559 -6.170141
#
# [70687 rows x 17 columns]

# %%
df_bands = df[['Bathymetry', 'B2', 'B3', 'B4', 'B5', 'B8', 'chl']]

# Correlations Matrix
corr = df_bands[df_bands['Bathymetry'] <= -5].corr()

# Fill diagonal and upper half with NaNs
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr[mask] = np.nan
(corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(color='#f1f1f1')  # Color NaNs grey
 .format(precision=2))
# Out:
# <style type="text/css">
# #T_1da36_row0_col0, #T_1da36_row0_col1, #T_1da36_row0_col2, #T_1da36_row0_col3, #T_1da36_row0_col4, #T_1da36_row0_col5, #T_1da36_row0_col6, #T_1da36_row1_col1, #T_1da36_row1_col2, #T_1da36_row1_col3, #T_1da36_row1_col4, #T_1da36_row1_col5, #T_1da36_row1_col6, #T_1da36_row2_col2, #T_1da36_row2_col3, #T_1da36_row2_col4, #T_1da36_row2_col5, #T_1da36_row2_col6, #T_1da36_row3_col3, #T_1da36_row3_col4, #T_1da36_row3_col5, #T_1da36_row3_col6, #T_1da36_row4_col4, #T_1da36_row4_col5, #T_1da36_row4_col6, #T_1da36_row5_col5, #T_1da36_row5_col6, #T_1da36_row6_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #f1f1f1;
# }
# #T_1da36_row1_col0 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_1da36_row2_col0 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_1da36_row2_col1 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_1da36_row3_col0, #T_1da36_row5_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_1da36_row3_col1 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_1da36_row3_col2 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_1da36_row4_col0 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_1da36_row4_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_1da36_row4_col2 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_1da36_row4_col3 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_1da36_row5_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_1da36_row5_col2 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_1da36_row5_col3 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_1da36_row5_col4 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_1da36_row6_col0, #T_1da36_row6_col2 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_1da36_row6_col1 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_1da36_row6_col3 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_1da36_row6_col4 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_1da36_row6_col5 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# </style>
# <table id="T_1da36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1da36_level0_col0" class="col_heading level0 col0" >Bathymetry</th>
#       <th id="T_1da36_level0_col1" class="col_heading level0 col1" >B2</th>
#       <th id="T_1da36_level0_col2" class="col_heading level0 col2" >B3</th>
#       <th id="T_1da36_level0_col3" class="col_heading level0 col3" >B4</th>
#       <th id="T_1da36_level0_col4" class="col_heading level0 col4" >B5</th>
#       <th id="T_1da36_level0_col5" class="col_heading level0 col5" >B8</th>
#       <th id="T_1da36_level0_col6" class="col_heading level0 col6" >chl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1da36_level0_row0" class="row_heading level0 row0" >Bathymetry</th>
#       <td id="T_1da36_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_1da36_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_1da36_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_1da36_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_1da36_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_1da36_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_1da36_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1da36_level0_row1" class="row_heading level0 row1" >B2</th>
#       <td id="T_1da36_row1_col0" class="data row1 col0" >0.56</td>
#       <td id="T_1da36_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_1da36_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_1da36_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_1da36_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_1da36_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_1da36_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1da36_level0_row2" class="row_heading level0 row2" >B3</th>
#       <td id="T_1da36_row2_col0" class="data row2 col0" >0.68</td>
#       <td id="T_1da36_row2_col1" class="data row2 col1" >0.95</td>
#       <td id="T_1da36_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_1da36_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_1da36_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_1da36_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_1da36_row2_col6" class="data row2 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1da36_level0_row3" class="row_heading level0 row3" >B4</th>
#       <td id="T_1da36_row3_col0" class="data row3 col0" >0.31</td>
#       <td id="T_1da36_row3_col1" class="data row3 col1" >0.43</td>
#       <td id="T_1da36_row3_col2" class="data row3 col2" >0.55</td>
#       <td id="T_1da36_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_1da36_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_1da36_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_1da36_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1da36_level0_row4" class="row_heading level0 row4" >B5</th>
#       <td id="T_1da36_row4_col0" class="data row4 col0" >0.33</td>
#       <td id="T_1da36_row4_col1" class="data row4 col1" >0.36</td>
#       <td id="T_1da36_row4_col2" class="data row4 col2" >0.48</td>
#       <td id="T_1da36_row4_col3" class="data row4 col3" >0.85</td>
#       <td id="T_1da36_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_1da36_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_1da36_row4_col6" class="data row4 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1da36_level0_row5" class="row_heading level0 row5" >B8</th>
#       <td id="T_1da36_row5_col0" class="data row5 col0" >0.17</td>
#       <td id="T_1da36_row5_col1" class="data row5 col1" >0.31</td>
#       <td id="T_1da36_row5_col2" class="data row5 col2" >0.35</td>
#       <td id="T_1da36_row5_col3" class="data row5 col3" >0.74</td>
#       <td id="T_1da36_row5_col4" class="data row5 col4" >0.67</td>
#       <td id="T_1da36_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_1da36_row5_col6" class="data row5 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1da36_level0_row6" class="row_heading level0 row6" >chl</th>
#       <td id="T_1da36_row6_col0" class="data row6 col0" >0.71</td>
#       <td id="T_1da36_row6_col1" class="data row6 col1" >0.54</td>
#       <td id="T_1da36_row6_col2" class="data row6 col2" >0.71</td>
#       <td id="T_1da36_row6_col3" class="data row6 col3" >0.54</td>
#       <td id="T_1da36_row6_col4" class="data row6 col4" >0.53</td>
#       <td id="T_1da36_row6_col5" class="data row6 col5" >0.20</td>
#       <td id="T_1da36_row6_col6" class="data row6 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_ratios = df[['Bathymetry', 'Rt23', 'Rt24', 'Rt28', 'Rt34', 'Rt38', 'Rt48']]

# Correlations Matrix
corr = df_ratios[df_ratios['Bathymetry'] <= -5].corr()

# Fill diagonal and upper half with NaNs
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr[mask] = np.nan
(corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(color='#f1f1f1')  # Color NaNs grey
 .format(precision=2))
# Out:
# <style type="text/css">
# #T_50dbf_row0_col0, #T_50dbf_row0_col1, #T_50dbf_row0_col2, #T_50dbf_row0_col3, #T_50dbf_row0_col4, #T_50dbf_row0_col5, #T_50dbf_row0_col6, #T_50dbf_row1_col1, #T_50dbf_row1_col2, #T_50dbf_row1_col3, #T_50dbf_row1_col4, #T_50dbf_row1_col5, #T_50dbf_row1_col6, #T_50dbf_row2_col2, #T_50dbf_row2_col3, #T_50dbf_row2_col4, #T_50dbf_row2_col5, #T_50dbf_row2_col6, #T_50dbf_row3_col3, #T_50dbf_row3_col4, #T_50dbf_row3_col5, #T_50dbf_row3_col6, #T_50dbf_row4_col4, #T_50dbf_row4_col5, #T_50dbf_row4_col6, #T_50dbf_row5_col5, #T_50dbf_row5_col6, #T_50dbf_row6_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #f1f1f1;
# }
# #T_50dbf_row1_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_50dbf_row2_col0 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_50dbf_row2_col1, #T_50dbf_row5_col2 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_50dbf_row3_col0 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_50dbf_row3_col1, #T_50dbf_row4_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_50dbf_row3_col2 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_50dbf_row4_col0 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_50dbf_row4_col2 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_50dbf_row4_col3 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_50dbf_row5_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_50dbf_row5_col1 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_50dbf_row5_col3 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_50dbf_row5_col4 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_50dbf_row6_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_50dbf_row6_col1, #T_50dbf_row6_col4 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_50dbf_row6_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_50dbf_row6_col3 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_50dbf_row6_col5 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_50dbf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50dbf_level0_col0" class="col_heading level0 col0" >Bathymetry</th>
#       <th id="T_50dbf_level0_col1" class="col_heading level0 col1" >Rt23</th>
#       <th id="T_50dbf_level0_col2" class="col_heading level0 col2" >Rt24</th>
#       <th id="T_50dbf_level0_col3" class="col_heading level0 col3" >Rt28</th>
#       <th id="T_50dbf_level0_col4" class="col_heading level0 col4" >Rt34</th>
#       <th id="T_50dbf_level0_col5" class="col_heading level0 col5" >Rt38</th>
#       <th id="T_50dbf_level0_col6" class="col_heading level0 col6" >Rt48</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50dbf_level0_row0" class="row_heading level0 row0" >Bathymetry</th>
#       <td id="T_50dbf_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_50dbf_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_50dbf_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_50dbf_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_50dbf_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_50dbf_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_50dbf_row0_col6" class="data row0 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_50dbf_level0_row1" class="row_heading level0 row1" >Rt23</th>
#       <td id="T_50dbf_row1_col0" class="data row1 col0" >-0.79</td>
#       <td id="T_50dbf_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_50dbf_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_50dbf_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_50dbf_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_50dbf_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_50dbf_row1_col6" class="data row1 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_50dbf_level0_row2" class="row_heading level0 row2" >Rt24</th>
#       <td id="T_50dbf_row2_col0" class="data row2 col0" >-0.21</td>
#       <td id="T_50dbf_row2_col1" class="data row2 col1" >0.45</td>
#       <td id="T_50dbf_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_50dbf_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_50dbf_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_50dbf_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_50dbf_row2_col6" class="data row2 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_50dbf_level0_row3" class="row_heading level0 row3" >Rt28</th>
#       <td id="T_50dbf_row3_col0" class="data row3 col0" >-0.16</td>
#       <td id="T_50dbf_row3_col1" class="data row3 col1" >0.22</td>
#       <td id="T_50dbf_row3_col2" class="data row3 col2" >0.50</td>
#       <td id="T_50dbf_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_50dbf_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_50dbf_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_50dbf_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_50dbf_level0_row4" class="row_heading level0 row4" >Rt34</th>
#       <td id="T_50dbf_row4_col0" class="data row4 col0" >-0.01</td>
#       <td id="T_50dbf_row4_col1" class="data row4 col1" >0.21</td>
#       <td id="T_50dbf_row4_col2" class="data row4 col2" >0.97</td>
#       <td id="T_50dbf_row4_col3" class="data row4 col3" >0.48</td>
#       <td id="T_50dbf_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_50dbf_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_50dbf_row4_col6" class="data row4 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_50dbf_level0_row5" class="row_heading level0 row5" >Rt38</th>
#       <td id="T_50dbf_row5_col0" class="data row5 col0" >-0.03</td>
#       <td id="T_50dbf_row5_col1" class="data row5 col1" >0.07</td>
#       <td id="T_50dbf_row5_col2" class="data row5 col2" >0.45</td>
#       <td id="T_50dbf_row5_col3" class="data row5 col3" >0.99</td>
#       <td id="T_50dbf_row5_col4" class="data row5 col4" >0.48</td>
#       <td id="T_50dbf_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_50dbf_row5_col6" class="data row5 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_50dbf_level0_row6" class="row_heading level0 row6" >Rt48</th>
#       <td id="T_50dbf_row6_col0" class="data row6 col0" >-0.03</td>
#       <td id="T_50dbf_row6_col1" class="data row6 col1" >-0.08</td>
#       <td id="T_50dbf_row6_col2" class="data row6 col2" >-0.09</td>
#       <td id="T_50dbf_row6_col3" class="data row6 col3" >0.78</td>
#       <td id="T_50dbf_row6_col4" class="data row6 col4" >-0.08</td>
#       <td id="T_50dbf_row6_col5" class="data row6 col5" >0.79</td>
#       <td id="T_50dbf_row6_col6" class="data row6 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_lyzenga = df[['Bathymetry', 'Lt2', 'Lt3', 'Lt4', 'Lt8']]

# Correlations Matrix
corr = df_lyzenga[df_lyzenga['Bathymetry'] <= -5].corr()

# Fill diagonal and upper half with NaNs
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr[mask] = np.nan
(corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(color='#f1f1f1')  # Color NaNs grey
 .format(precision=2))
# Out:
# <style type="text/css">
# #T_b4acf_row0_col0, #T_b4acf_row0_col1, #T_b4acf_row0_col2, #T_b4acf_row0_col3, #T_b4acf_row0_col4, #T_b4acf_row1_col1, #T_b4acf_row1_col2, #T_b4acf_row1_col3, #T_b4acf_row1_col4, #T_b4acf_row2_col2, #T_b4acf_row2_col3, #T_b4acf_row2_col4, #T_b4acf_row3_col3, #T_b4acf_row3_col4, #T_b4acf_row4_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #f1f1f1;
# }
# #T_b4acf_row1_col0 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_b4acf_row2_col0 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_b4acf_row2_col1 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_b4acf_row3_col0, #T_b4acf_row4_col1 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_b4acf_row3_col1 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_b4acf_row3_col2 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_b4acf_row4_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_b4acf_row4_col2 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_b4acf_row4_col3 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# </style>
# <table id="T_b4acf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4acf_level0_col0" class="col_heading level0 col0" >Bathymetry</th>
#       <th id="T_b4acf_level0_col1" class="col_heading level0 col1" >Lt2</th>
#       <th id="T_b4acf_level0_col2" class="col_heading level0 col2" >Lt3</th>
#       <th id="T_b4acf_level0_col3" class="col_heading level0 col3" >Lt4</th>
#       <th id="T_b4acf_level0_col4" class="col_heading level0 col4" >Lt8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4acf_level0_row0" class="row_heading level0 row0" >Bathymetry</th>
#       <td id="T_b4acf_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_b4acf_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_b4acf_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_b4acf_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_b4acf_row0_col4" class="data row0 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b4acf_level0_row1" class="row_heading level0 row1" >Lt2</th>
#       <td id="T_b4acf_row1_col0" class="data row1 col0" >0.49</td>
#       <td id="T_b4acf_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_b4acf_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_b4acf_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_b4acf_row1_col4" class="data row1 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b4acf_level0_row2" class="row_heading level0 row2" >Lt3</th>
#       <td id="T_b4acf_row2_col0" class="data row2 col0" >0.65</td>
#       <td id="T_b4acf_row2_col1" class="data row2 col1" >0.89</td>
#       <td id="T_b4acf_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_b4acf_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_b4acf_row2_col4" class="data row2 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b4acf_level0_row3" class="row_heading level0 row3" >Lt4</th>
#       <td id="T_b4acf_row3_col0" class="data row3 col0" >0.30</td>
#       <td id="T_b4acf_row3_col1" class="data row3 col1" >0.51</td>
#       <td id="T_b4acf_row3_col2" class="data row3 col2" >0.56</td>
#       <td id="T_b4acf_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_b4acf_row3_col4" class="data row3 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b4acf_level0_row4" class="row_heading level0 row4" >Lt8</th>
#       <td id="T_b4acf_row4_col0" class="data row4 col0" >0.14</td>
#       <td id="T_b4acf_row4_col1" class="data row4 col1" >0.30</td>
#       <td id="T_b4acf_row4_col2" class="data row4 col2" >0.29</td>
#       <td id="T_b4acf_row4_col3" class="data row4 col3" >0.39</td>
#       <td id="T_b4acf_row4_col4" class="data row4 col4" >nan</td>
#     </tr>
#   </tbody>
# </table>
